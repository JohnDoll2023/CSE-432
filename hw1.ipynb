# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnDoll2023/CSE-432/blob/main/hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 1 of Homework1

# %%
import numpy as np

# checks if parameter is a matrix
def isMatrix(A):
  if isinstance(A[0], np.ndarray) or isinstance(A[0], list):
    return True
  return False

# returns dot product of two parameters if applicable
def MultiDot(A, B):
  # checks what types the inputs are
  AisMatrix = isMatrix(A)
  BisMatrix = isMatrix(B)

  # first case where both parameters are vectors
  if not AisMatrix and not BisMatrix:
    if len(A) == len(B):
      sum = 0
      for i in range(0, len(A)):
        sum += A[i] * B[i]
      return sum
    else:
      return "Dimension mismatch in vector dot product."

  # second case where first parameter is matrix and the other is a vector
  elif AisMatrix and not BisMatrix:
    if len(A[0]) == len(B):
      result = []
      for i in range(0, len(A)):
        for j in range(0, len(B)):
          sum = 0
          for k in range(0, len(B)):
            sum += A[i][k] * B[k]
        result.append(sum)
      return result
    else:
      return "Dimension mismatch in Matrix x vector dot product"

  # third case where first parameter is vector and second is matrix
  elif not AisMatrix and BisMatrix:
    print('here')
    if len(B) == len(A):
      result = []
      for i in range(0, len(B[0])):
        for j in range(0, len(B[0])):
          sum = 0
          for k in range(0, len(A)):
            sum += B[k][i] * A[k]
        result.append(sum)
      return result
    else:
      return "Dimension mismatch in vector x Matrix dot product"

  # fourth case where both parameters are matrices
  else:
    if len(A[0]) == len(B):
      result = []
      for i in range(0, len(A)):
        row = []
        for j in range(0, len(B[0])):
          sum = 0
          for k in range(0, len(B)):
            sum += A[i][k] * B[k][j]
          row.append(sum)
        result.append(row)
      return result
    else:
      return "Dimension mismatch in matrix dot product"

# %% [markdown]
# Bonus of Homework1

# %%
import pandas as pd
import folium

# read in the needed data
df = pd.read_csv('california_housing_test.csv', usecols = ['latitude','longitude','median_house_value'])

# create a map for plotting
map = folium.Map(width=700, height = 700, location=[37, -122], zoom_start=6)

# plot each point at the latitude and longitude points, with the circle radius
# size corresponding to median house value
for i in range(1, len(df)):
  marker = folium.CircleMarker(
      location=[df['latitude'][i], df['longitude'][i]],
      radius=np.interp(df['median_house_value'][i], [22500, 500001], [1, 20]),
      icon=folium.Icon(color="green"))
  marker.add_to(map)

# plot the point
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
